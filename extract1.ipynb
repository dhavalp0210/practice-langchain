# %%
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
import io

# Path to your PDF file
pdf_path = 'gujarati-demo.pdf'

# Path to Tesseract executable (adjust if necessary)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # Windows example

# Open the PDF
doc = fitz.open(pdf_path)

# Initialize an empty string to store extracted text
extracted_text = ""

# Iterate through each page
for page_num in range(len(doc)):
    page = doc.load_page(page_num)
    
    # Convert the page to an image
    pix = page.get_pixmap()
    img = Image.open(io.BytesIO(pix.tobytes()))
    
    # Perform OCR on the image with Gujarati language
    text = pytesseract.image_to_string(img,lang='guj+san')
    
    # Append the extracted text
    extracted_text += text

# Print the extracted text
print(extracted_text)
# Out:
# ઝટ
# श्री परमात्मने नमः
#
# યથાર્થ ગીતા
# (શ્રીમદ્ભગવદ્‌ગીતા)
#
# અધ્યાય પહેલો
# કુત उवाचः
# मे कुरर समवेता युयुत्सवः ।
# मामकाः पाणडवाश्व किमक संजय ।॥९॥
# ધૂતરાષ્ટ્ર સંજયને પૂછે છે કે “ ५३०३५ ३३०५५ યુદ્ધ માટે એકઠા
# થથેલા મારા પુત્રો તથા પાંડવોએ શું કર્યુ ?”
# ધૂતરાષ્ટ્ર એ અજ્ઞાન અને સંજય એ સંયમ. અજ્ઞાન, મનની અંદર ઉડે
# ઊડે રહે છે. અજ્ઞાનથી આવૃત મનવાળા ધૃતરાષ્ટ્ર જન્મથી અંધ છે, પરંતુ તે
# સંથમરૂપી સંજયના માધ્યમથી જુએ છે - સાંભળે છે. એ સમજે છે ખરો કે
# પરમાત્મા સત્ય છે, છતાં એના પોતાનાથી ઉત્પન્ન થયેલ મોટરૂપી દુર્યોધન
# જીવિત છે ત્યાં સુધી એની ध હંમેશાં કૌરવો એટલે કે વિકારો પર રહે છે.
# ધર્મ એક ક્ષેત્ર છે.કદય-દેશમાં દૈવી સંપત્તિ વિપુલ પ્રમાશમાં હોય
# ત્યારે આ શરીર ધર્ષકષત્ર બની જાય છે અને જ્યારે એમાં આસુરી સંપત્તિ
# વિશેષ પ્રમાણમાં હોય ત્યારે આ શરીર उ म જાય છે. (ध) એટલે
# કરો. આ શબ્દ આદેશાત્મક છે. શ્રીકૃષ્ણ કહે છે, પ્રકૃતિથી ઉત્પન્ન ત્રશ
#
# २ ५५५ ગીતા
#
# ગુ્રો દ્વાર પરવશ માનવી કર્મ કરે છે, તે એક ક્ષણ પલ કર્મ કર્યા વિના
# રહી શક્તો નથી. ત્રણે ગુણો તેની પાસે કર્મ કરાવી લે છે. સુઈ જાઓ
# ...

# %%
pytesseract.image_to_string()

# %%
import pytesseract
from pdf2image import convert_from_path
import glob

pdfs = glob.glob("gujarati.pdf")

for pdf_path in pdfs:
    pages = convert_from_path(pdf_path, 500)

    for pageNum,imgBlob in enumerate(pages):
        text = pytesseract.image_to_string(imgBlob,lang='eng')

        with open(f'{pdf_path}.txt', 'a') as the_file:
            the_file.write(text)
